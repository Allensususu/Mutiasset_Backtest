# %%
# !pip install ffn
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: ffn in c:\users\allen\anaconda3\lib\site-packages (0.3.6)
# Requirement already satisfied: scipy>=0.15 in c:\users\allen\anaconda3\lib\site-packages (from ffn) (1.9.1)
# Requirement already satisfied: matplotlib>=1 in c:\users\allen\appdata\roaming\python\python39\site-packages (from ffn) (3.5.2)
# Requirement already satisfied: scikit-learn>=0.15 in c:\users\allen\anaconda3\lib\site-packages (from ffn) (0.24.2)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\allen\anaconda3\lib\site-packages (from ffn) (0.8.9)
# Requirement already satisfied: future>=0.15 in c:\users\allen\anaconda3\lib\site-packages (from ffn) (0.18.2)
# Requirement already satisfied: pandas-datareader>=0.2 in c:\users\allen\anaconda3\lib\site-packages (from ffn) (0.10.0)
# Requirement already satisfied: decorator>=4 in c:\users\allen\appdata\roaming\python\python39\site-packages (from ffn) (5.1.1)
# Requirement already satisfied: numpy>=1.5 in c:\users\allen\anaconda3\lib\site-packages (from ffn) (1.23.5)
# Requirement already satisfied: pandas>=0.19 in c:\users\allen\anaconda3\lib\site-packages (from ffn) (1.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib>=1->ffn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib>=1->ffn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib>=1->ffn) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib>=1->ffn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib>=1->ffn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib>=1->ffn) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib>=1->ffn) (1.4.4)
# Requirement already satisfied: pytz>=2017.2 in c:\users\allen\appdata\roaming\python\python39\site-packages (from pandas>=0.19->ffn) (2022.1)
# Requirement already satisfied: lxml in c:\users\allen\anaconda3\lib\site-packages (from pandas-datareader>=0.2->ffn) (4.8.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\allen\appdata\roaming\python\python39\site-packages (from pandas-datareader>=0.2->ffn) (2.28.1)
# Requirement already satisfied: six>=1.5 in c:\users\allen\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib>=1->ffn) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\allen\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\allen\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (1.26.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\allen\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\allen\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (3.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\allen\appdata\roaming\python\python39\site-packages (from scikit-learn>=0.15->ffn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\allen\appdata\roaming\python\python39\site-packages (from scikit-learn>=0.15->ffn) (3.1.0)
# Requirement already satisfied: pandas in c:\users\allen\anaconda3\lib\site-packages (1.1.4)
# Requirement already satisfied: pytz>=2017.2 in c:\users\allen\appdata\roaming\python\python39\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\allen\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\allen\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\allen\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\allen\appdata\roaming\python\python39\site-packages (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\allen\appdata\roaming\python\python39\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\allen\anaconda3\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\allen\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
import ffn
import pandas as pd 

#################
#輸入回測之資產 (需要至Yahoo財經查看代碼)

##範例1
#asset = "1101.TW,1102.TW,1215.TW,3430.TWO"

##範例2
#asset = "QQQ,TQQQ,SPY"

##回測資產輸入
asset ="2330.TW,0050.TW,QQQ"

##權重分配(非必填) ，依照需要回測個數填入相加等於1之值 ,若填空會產出平均分配1組並另外隨機生成10組權重
#Proportion = [0.3,0.3,0.3,0.1] 若有四項資產則即前三檔占比0.3,第四檔占比0.1。
#Proportion = [0.2,0.2,0.2,0.2,0.1,0.1] 若有六項資產可參考此Proportion，算四項占比0.2，後兩項占比0.1

Proportion = []
#################

prices = ffn.get(asset,start='2017-01-01' )#,itot,gld,ivv,uso

prices.to_csv('大擂台用.csv',encoding="utf_8_sig")

prices.rebase().plot()  #畫每個資產走勢
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # 創造資產組合

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random


strategies = {}

"""
asset_per = np.zeros((int(len(prices.columns)),int(len(prices.columns))), dtype=float)
for num in range(0,len(prices.columns)) :
    asset_per[num][num] = 1 
    strategies[prices.columns[num]] = (prices.rebase() * asset_per[num]).mean(axis=1).rebase()
"""
# %matplotlib inline
if Proportion == [] :
    strategies['average-asset'] = (prices.rebase() * (np.full(len(prices.columns),1/len(prices.columns)))).mean(axis=1).rebase()
    print("平均分配權重")
    print('average-asset' ,asset ,np.full(len(prices.columns),1/len(prices.columns)))
    print("隨機生成之權重")
    average = np.full(len(prices.columns),1/len(prices.columns))
    for i in range(0,10):
        for _ in range(0,10000):
            random_folat = random.uniform(0.01, 0.05)
            random1 = random.randrange(len(prices.columns))
            random2 = random.randrange(len(prices.columns))
            if average[random2] - random_folat > 0:
                average[random1] = average[random1] + random_folat
                average[random2] = average[random2] - random_folat
       
        print('mutiple_asset' + str(i+1),asset ,average)
        strategies['mutiple_asset' + str(i+1)] = (prices.rebase() * average).mean(axis=1).rebase()

else :
    print("權重")
    strategies['Proportion'] = (prices.rebase() * Proportion).mean(axis=1).rebase()
    print('Proportion',asset ,Proportion )
    
strategies = pd.DataFrame(strategies)
strategies.plot()

#隱藏警告 並計算stats
import warnings
warnings.filterwarnings('ignore')

stats = strategies.calc_stats()
stats = pd.DataFrame(
    {
        name:pd.Series({key:getattr(pf, key) for key in dir(pf) if isinstance(getattr(pf, key), float)}, name=name) 
        for name,pf in stats.items()
    }).transpose()
print("\n")
print("stats可以使用參數")
print(stats.columns)
# Out:
# 平均分配權重
# average-asset 2330.TW,0050.TW,QQQ [0.33333333 0.33333333 0.33333333]
# 隨機生成之權重
# mutiple_asset1 2330.TW,0050.TW,QQQ [0.3102753  0.48568371 0.204041  ]
# mutiple_asset2 2330.TW,0050.TW,QQQ [0.07412837 0.66255471 0.26331692]
# mutiple_asset3 2330.TW,0050.TW,QQQ [0.26143846 0.31548949 0.42307205]
# mutiple_asset4 2330.TW,0050.TW,QQQ [0.11056493 0.63895494 0.25048013]
# mutiple_asset5 2330.TW,0050.TW,QQQ [0.64800666 0.32630006 0.02569328]
# mutiple_asset6 2330.TW,0050.TW,QQQ [0.46246898 0.22303226 0.31449876]
# mutiple_asset7 2330.TW,0050.TW,QQQ [0.24430539 0.01998294 0.73571167]
# mutiple_asset8 2330.TW,0050.TW,QQQ [0.11416604 0.72800649 0.15782747]
# mutiple_asset9 2330.TW,0050.TW,QQQ [0.27649032 0.29208915 0.43142053]
# mutiple_asset10 2330.TW,0050.TW,QQQ [0.40756861 0.13156961 0.46086178]
#
#
# stats可以使用參數
# Index(['avg_down_month', 'avg_drawdown', 'avg_drawdown_days', 'avg_up_month',
#        'best_day', 'best_month', 'best_year', 'cagr', 'calmar', 'daily_kurt',
#        'daily_mean', 'daily_sharpe', 'daily_skew', 'daily_sortino',
#        'daily_vol', 'five_year', 'incep', 'max_drawdown', 'monthly_kurt',
#        'monthly_mean', 'monthly_sharpe', 'monthly_skew', 'monthly_sortino',
#        'monthly_vol', 'mtd', 'one_year', 'pos_month_perc', 'rf', 'six_month',
#        'ten_year', 'three_month', 'three_year', 'total_return',
#        'twelve_month_win_perc', 'win_year_perc', 'worst_day', 'worst_month',
#        'worst_year', 'yearly_kurt', 'yearly_mean', 'yearly_sharpe',
#        'yearly_skew', 'yearly_sortino', 'yearly_vol', 'ytd'],
#       dtype='object')

# %% [markdown]
# # 資產回測結果

# %%
strategies.plot()
print("年化報酬")
print(stats.cagr)
print("最大回撤:")
print(stats.max_drawdown)
print("夏普值")
print(stats.daily_sharpe)
# Out:
# 年化報酬
# average-asset      0.162968
# mutiple_asset1     0.150684
# mutiple_asset2     0.122236
# mutiple_asset3     0.160252
# mutiple_asset4     0.126559
# mutiple_asset5     0.180132
# mutiple_asset6     0.177371
# mutiple_asset7     0.179492
# mutiple_asset8     0.119364
# mutiple_asset9     0.162738
# mutiple_asset10    0.180555
# Name: cagr, dtype: float64
# 最大回撤:
# average-asset     -0.368145
# mutiple_asset1    -0.369773
# mutiple_asset2    -0.347863
# mutiple_asset3    -0.362249
# mutiple_asset4    -0.351448
# mutiple_asset5    -0.418665
# mutiple_asset6    -0.377118
# mutiple_asset7    -0.358420
# mutiple_asset8    -0.352423
# mutiple_asset9    -0.363215
# mutiple_asset10   -0.371169
# Name: max_drawdown, dtype: float64
# 夏普值
# average-asset      0.978109
# mutiple_asset1     0.904014
# mutiple_asset2     0.832440
# mutiple_asset3     0.978813
# mutiple_asset4     0.846726
# mutiple_asset5     0.874812
# mutiple_asset6     1.005690
# mutiple_asset7     0.972188
# mutiple_asset8     0.789037
# mutiple_asset9     0.986685
# mutiple_asset10    1.038848
# Name: daily_sharpe, dtype: float64
